# %% [markdown]
# ## Train a simple convnet on the Fashion MNIST dataset

# %% [markdown]
# In this, we will see how to deal with image data and train a convnet for image classification task.

# %% [markdown]
# ### Load the  `fashion_mnist`  dataset
#
# ** Use keras.datasets to load the dataset **

# %%
import numpy as np
import matplotlib.pyplot as plt
import codecs,datetime, glob, itertools, keras, os, pickle
import re, sklearn, string, sys, tensorflow, time
from random import randint
from keras import backend as K, regularizers, optimizers
from keras.models import load_model, Sequential
from keras.layers import MaxPooling2D, Convolution2D, Activation, Dropout, Flatten, Dense, InputLayer
from keras.layers.normalization import BatchNormalization
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.utils import np_utils
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, confusion_matrix, f1_score

print('Keras version: \t\t%s' % keras.__version__)
print('Scikit version: \t%s' % sklearn.__version__)
print('TensorFlow version: \t%s' % tensorflow.__version__)
# Out:
# Keras version: 		2.2.4
# Scikit version: 	0.21.3
# TensorFlow version: 	1.14.0

# %%
from keras.datasets import fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %% [markdown]
# ### Find no.of samples are there in training and test datasets

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
y_test.shape
# Out:
# (10000,)

# %% [markdown]
# ### Find dimensions of an image in the dataset

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
for i in range(1):
    image = x_train[i]
    plt.figure(i)
    plt.imshow(image)

# %%
x_train[0,:,:].shape
# Out:
# (28, 28)

# %% [markdown]
# ### Convert train and test labels to one hot vectors
#
# ** check `keras.utils.to_categorical()` **

# %%
import tensorflow as tf
tf.set_random_seed(42)
import keras
from keras.datasets import mnist
from keras.layers import Dense
from keras.models import Sequential
from keras.optimizers import SGD
import matplotlib.pyplot as plt
from keras.preprocessing import image
y_train = tf.keras.utils.to_categorical(y_train, num_classes=10)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=10)

# %% [markdown]
# ### Normalize both the train and test image data from 0-255 to 0-1

# %%
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

# %% [markdown]
# ### Reshape the data from 28x28 to 28x28x1 to match input dimensions in Conv2D layer in keras

# %%
w, h = 28, 28
x_train = x_train.reshape(x_train.shape[0], w, h, 1)
x_test = x_test.reshape(x_test.shape[0], w, h, 1)

# %%
x_train.shape
# Out:
# (60000, 28, 28, 1)

# %% [markdown]
# ### Import the necessary layers from keras to build the model

# %%
# already done

# %% [markdown]
# ### Build a model
#
# ** with 2 Conv layers having `32 3x3 filters` in both convolutions with `relu activations` and `flatten` before passing the feature map into 2 fully connected layers (or Dense Layers) having 128 and 10 neurons with `relu` and `softmax` activations respectively. Now, using `categorical_crossentropy` loss with `adam` optimizer train the model with early stopping `patience=5` and no.of `epochs=10`. **

# %%
#Initialize sequential model
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Conv2D(32, #Number of filters 
                                kernel_size=(3,3), #Size of the filter
                                activation='relu'))

#Add second convolutional layer
model.add(tf.keras.layers.Conv2D(32, kernel_size=(3,3), activation='relu'))
#Flatten the output
model.add(tf.keras.layers.Flatten())
#Dense layer
model.add(tf.keras.layers.Dense(128, activation='relu'))
#Output layer
model.add(tf.keras.layers.Dense(10, activation='softmax'))
#Complie the model
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
#model.fit(x_train,y_train,epochs=10,validation_data=(x_test,y_test),batch_size=32)

# %% [markdown]
# ### Now, to the above model add `max` pooling layer of `filter size 2x2` and `dropout` layer with `p=0.25` after the 2 conv layers and run the model

# %%
#Initialize sequential model
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Conv2D(32, #Number of filters 
                                kernel_size=(3,3), #Size of the filter
                                activation='relu'))

#Add second convolutional layer
model.add(tf.keras.layers.Conv2D(32, kernel_size=(3,3), activation='relu'))
# Conv + Maxpooling
#model.add(Convolution2D(32, (2, 2), activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=2))
model.add(tf.keras.layers.Dropout(0.25))
#Flatten the output
model.add(tf.keras.layers.Flatten())
#Dense layer
model.add(tf.keras.layers.Dense(128, activation='relu'))
#Output layer
model.add(tf.keras.layers.Dense(10, activation='softmax'))
#Complie the model
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
model.fit(x_train,y_train,epochs=10,validation_data=(x_test,y_test),batch_size=32)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/10
# 60000/60000 [==============================] - 8s 133us/sample - loss: 0.3925 - acc: 0.8578 - val_loss: 0.2913 - val_acc: 0.8961
# Epoch 2/10
# 60000/60000 [==============================] - 7s 123us/sample - loss: 0.2536 - acc: 0.9064 - val_loss: 0.2486 - val_acc: 0.9085
# Epoch 3/10
# 60000/60000 [==============================] - 7s 124us/sample - loss: 0.2089 - acc: 0.9229 - val_loss: 0.2336 - val_acc: 0.9144
# Epoch 4/10
# 60000/60000 [==============================] - 7s 123us/sample - loss: 0.1736 - acc: 0.9351 - val_loss: 0.2136 - val_acc: 0.9237
# Epoch 5/10
# 60000/60000 [==============================] - 7s 123us/sample - loss: 0.1456 - acc: 0.9459 - val_loss: 0.2410 - val_acc: 0.9161
# Epoch 6/10
# 60000/60000 [==============================] - 7s 123us/sample - loss: 0.1239 - acc: 0.9539 - val_loss: 0.2549 - val_acc: 0.9179
# Epoch 7/10
# 60000/60000 [==============================] - 7s 124us/sample - loss: 0.1053 - acc: 0.9603 - val_loss: 0.2485 - val_acc: 0.9222
# Epoch 8/10
# 60000/60000 [==============================] - 7s 121us/sample - loss: 0.0909 - acc: 0.9662 - val_loss: 0.2581 - val_acc: 0.9212
# Epoch 9/10
# 60000/60000 [==============================] - 7s 123us/sample - loss: 0.0772 - acc: 0.9706 - val_loss: 0.2774 - val_acc: 0.9246
# Epoch 10/10
# 60000/60000 [==============================] - 7s 123us/sample - loss: 0.0710 - acc: 0.9737 - val_loss: 0.2702 - val_acc: 0.9269

# %% [markdown]
# ### Now, to the above model, lets add Data Augmentation

# %% [markdown]
# ### Import the ImageDataGenrator from keras and fit the training images

# %%
datagen = ImageDataGenerator()
#datagen = ImageDataGenerator(
#   featurewise_center=True,
#   featurewise_std_normalization=True,
#   rotation_range=20,
#   width_shift_range=0.2,
#   height_shift_range=0.2,
#   horizontal_flip=True)
#datagen = ImageDataGenerator(
#   featurewise_center=True,
#   featurewise_std_normalization=True)

# %% [markdown]
# #### Showing 5 versions of the first image in training dataset using image datagenerator.flow()

# %%
from matplotlib import pyplot as plt
gen = datagen.flow(x_train[0:1], batch_size=1)
for i in range(1, 6):
    plt.subplot(1,5,i)
    plt.axis("off")
    plt.imshow(gen.next().squeeze(), cmap='gray')
    plt.plot()
plt.show()

# %% [markdown]
# ### Run the above model using fit_generator()

# %%
datagen.fit(x_train)
model.fit_generator(datagen.flow(x_train, y_train, batch_size=32), steps_per_epoch=len(x_train) / 32,validation_data=(x_test,y_test), epochs=20)
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 10s 6ms/step - loss: 0.0609 - acc: 0.9779 - val_loss: 0.2989 - val_acc: 0.9208
# Epoch 2/20
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0551 - acc: 0.9798 - val_loss: 0.3307 - val_acc: 0.9228
# Epoch 3/20
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0485 - acc: 0.9820 - val_loss: 0.3184 - val_acc: 0.9265
# Epoch 4/20
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0449 - acc: 0.9833 - val_loss: 0.3686 - val_acc: 0.9242
# Epoch 5/20
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0433 - acc: 0.9842 - val_loss: 0.3528 - val_acc: 0.9226
# Epoch 6/20
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0394 - acc: 0.9853 - val_loss: 0.3593 - val_acc: 0.9270
# Epoch 7/20
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0379 - acc: 0.9862 - val_loss: 0.3587 - val_acc: 0.9273
# Epoch 8/20
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0348 - acc: 0.9875 - val_loss: 0.3905 - val_acc: 0.9216
# Epoch 9/20
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0346 - acc: 0.9876 - val_loss: 0.4186 - val_acc: 0.9238
# Epoch 10/20
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0324 - acc: 0.9884 - val_loss: 0.3792 - val_acc: 0.9280
# Epoch 11/20
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0287 - acc: 0.9892 - val_loss: 0.3921 - val_acc: 0.9225
# Epoch 12/20
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0298 - acc: 0.9892 - val_loss: 0.4114 - val_acc: 0.9272
# Epoch 13/20
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0261 - acc: 0.9909 - val_loss: 0.4296 - val_acc: 0.9251
# Epoch 14/20
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0277 - acc: 0.9906 - val_loss: 0.4490 - val_acc: 0.9244
# Epoch 15/20
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0260 - acc: 0.9911 - val_loss: 0.4607 - val_acc: 0.9261
# Epoch 16/20
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0257 - acc: 0.9911 - val_loss: 0.4543 - val_acc: 0.9259
# Epoch 17/20
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0265 - acc: 0.9911 - val_loss: 0.4447 - val_acc: 0.9244
# Epoch 18/20
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0244 - acc: 0.9915 - val_loss: 0.4677 - val_acc: 0.9254
# Epoch 19/20
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0237 - acc: 0.9919 - val_loss: 0.4549 - val_acc: 0.9256
# Epoch 20/20
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.0219 - acc: 0.9924 - val_loss: 0.4834 - val_acc: 0.9256

# %% [markdown]
# ###  Report the final train and validation accuracy

# %%
# Evaluate the model on test set
score = model.evaluate(x_test, y_test, verbose=0)

# Print test accuracy
print('\n', 'Test accuracy:', score[1])
# Out:
#  Test accuracy: 0.9256

# %% [markdown]
# ## **DATA AUGMENTATION ON CIFAR10 DATASET**

# %% [markdown]
# One of the best ways to improve the performance of a Deep Learning model is to add more data to the training set. Aside from gathering more instances from the wild that are representative of the distinction task, we want to develop a set of methods that enhance the data we already have. There are many ways to augment existing datasets and produce more robust models. In the image domain, these are done to utilize the full power of the convolutional neural network, which is able to capture translational invariance. This translational invariance is what makes image recognition such a difficult task in the first place. You want the dataset to be representative of the many different positions, angles, lightings, and miscellaneous distortions that are of interest to the vision task.

# %% [markdown]
# ### **Import neessary libraries for data augmentation**

# %%
import tensorflow as tf
import numpy as np                                
import matplotlib.pyplot as plt
from tensorflow.examples.tutorials.mnist import input_data
import keras as k
from keras.datasets import cifar10
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
from keras.optimizers import SGD, Adam
from keras.regularizers import l2
import h5py
from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# ### **Load CIFAR10 dataset**

# %%
#load data
(x_train, y_train), (x_test, y_test) = cifar10.load_data()
img_rows, img_cols , channels= 32,32,3
for i in range(0,9):
    plt.subplot(330 + 1 + i)
    plt.imshow(x_train[i])
plt.show()
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 14s 0us/step

# %% [markdown]
# ### **Create a data_gen funtion to genererator with image rotation,shifting image horizontally and vertically with random flip horizontally.**

# %%
# set up image augmentation
datagen1 = ImageDataGenerator(
    rotation_range=15,
    horizontal_flip=True,
    width_shift_range=0.1,
    height_shift_range=0.1
         )
datagen1.fit(x_train)

# %% [markdown]
# ### **Prepare/fit the generator.**

# %%
model.fit_generator(datagen1.flow(x_train, y_train, batch_size=32), steps_per_epoch=len(x_train) / 32,validation_data=(x_test,y_test), epochs=20)
# Out:
# Epoch 1/20
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.5820 - acc: 0.7909 - val_loss: 0.2869 - val_acc: 0.9007
# Epoch 2/20
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.4259 - acc: 0.8422 - val_loss: 0.2784 - val_acc: 0.9050
# Epoch 3/20
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.3884 - acc: 0.8571 - val_loss: 0.2660 - val_acc: 0.9082
# Epoch 4/20
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.3653 - acc: 0.8661 - val_loss: 0.2706 - val_acc: 0.9059
# Epoch 5/20
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.3483 - acc: 0.8724 - val_loss: 0.2788 - val_acc: 0.9030
# Epoch 6/20
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.3361 - acc: 0.8757 - val_loss: 0.2647 - val_acc: 0.9073
# Epoch 7/20
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.3260 - acc: 0.8786 - val_loss: 0.2650 - val_acc: 0.9092
# Epoch 8/20
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.3177 - acc: 0.8816 - val_loss: 0.2603 - val_acc: 0.9079
# Epoch 9/20
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.3142 - acc: 0.8831 - val_loss: 0.2523 - val_acc: 0.9076
# Epoch 10/20
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.3076 - acc: 0.8876 - val_loss: 0.2716 - val_acc: 0.9053
# Epoch 11/20
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.2971 - acc: 0.8903 - val_loss: 0.2742 - val_acc: 0.9025
# Epoch 12/20
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.2978 - acc: 0.8905 - val_loss: 0.2437 - val_acc: 0.9151
# Epoch 13/20
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.2939 - acc: 0.8926 - val_loss: 0.2389 - val_acc: 0.9155
# Epoch 14/20
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.2892 - acc: 0.8928 - val_loss: 0.2530 - val_acc: 0.9132
# Epoch 15/20
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.2834 - acc: 0.8964 - val_loss: 0.2508 - val_acc: 0.9131
# Epoch 16/20
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.2792 - acc: 0.8976 - val_loss: 0.2425 - val_acc: 0.9138
# Epoch 17/20
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.2826 - acc: 0.8953 - val_loss: 0.2362 - val_acc: 0.9174
# Epoch 18/20
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.2762 - acc: 0.8984 - val_loss: 0.2584 - val_acc: 0.9147
# Epoch 19/20
# 1875/1875 [==============================] - 18s 10ms/step - loss: 0.2749 - acc: 0.8982 - val_loss: 0.2481 - val_acc: 0.9143
# Epoch 20/20
# 1875/1875 [==============================] - 18s 9ms/step - loss: 0.2707 - acc: 0.8990 - val_loss: 0.2656 - val_acc: 0.9074

# %% [markdown]
# ### **Generate 5 images for 1 of the image of CIFAR10 train dataset.**

# %%
from matplotlib import pyplot as plt
gen = datagen1.flow(x_train[0:1], batch_size=1)
for i in range(1, 6):
    plt.subplot(1,5,i)
    plt.axis("off")
    plt.imshow(gen.next().squeeze(), cmap='gray')
    plt.plot()
plt.show()
